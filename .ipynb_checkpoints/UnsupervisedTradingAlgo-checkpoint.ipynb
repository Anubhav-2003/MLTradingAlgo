# %% [markdown]
# # Stock Market Analysis

# %%
# !pip install pandas numpy matplotlib statsmodels pandas-datareader datetime yfinance scikit-learn PyPortfolioOpt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (3.9.0)
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 13.5 MB/s eta 0:00:00
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 19.1 MB/s eta 0:00:00
# Collecting yfinance
#   Downloading yfinance-0.2.54-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (1.5.0)
# Collecting PyPortfolioOpt
#   Downloading pyportfolioopt-1.5.6-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.11/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from statsmodels) (1.13.1)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/lib64/python3.11/site-packages (from pandas-datareader) (4.9.2)
# Requirement already satisfied: requests>=2.19.0 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas-datareader) (2.32.3)
# Collecting zope.interface
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 16.4 MB/s eta 0:00:00
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from yfinance) (4.1.0)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.9.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 20.2 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/lib/python3.11/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Collecting cvxpy>=1.1.19
#   Downloading cvxpy-1.6.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Collecting ecos<3.0.0,>=2.0.14
#   Downloading ecos-2.0.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.1/220.1 kB 37.4 MB/s eta 0:00:00
# Collecting plotly<6.0.0,>=5.0.0
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 11.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: soupsieve>1.2 in /usr/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Collecting osqp>=0.6.2
#   Downloading osqp-0.6.7.post3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 kB 12.6 MB/s eta 0:00:00
# Collecting clarabel>=0.5.0
#   Downloading clarabel-0.10.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting scs>=3.2.4.post1
#   Downloading scs-3.2.7.post2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 9.7 MB/s eta 0:00:000m eta 0:00:010:011
# Collecting tenacity>=6.2.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.24)
# Requirement already satisfied: setuptools in /usr/lib/python3.11/site-packages (from zope.interface->datetime) (65.5.1)
# Collecting qdldl
#   Downloading qdldl-0.1.7.post5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.8 MB/s eta 0:00:0031m36.0 MB/s eta 0:00:01
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139080 sha256=1d896a5e0f951cd0530e8d87bc087cc8f1d6bae20d52989b2a432eea6828ae90
#   Stored in directory: /home/anubhavbanerjee/.cache/pip/wheels/ed/fd/80/48a915968e77972758d473495648213961ac6a251fff460d67
# Successfully built peewee
# Installing collected packages: peewee, multitasking, zope.interface, tenacity, patsy, frozendict, scs, qdldl, plotly, ecos, datetime, clarabel, yfinance, statsmodels, pandas-datareader, osqp, cvxpy, PyPortfolioOpt
# Successfully installed PyPortfolioOpt-1.5.6 clarabel-0.10.0 cvxpy-1.6.4 datetime-5.5 ecos-2.0.14 frozendict-2.4.6 multitasking-0.0.11 osqp-0.6.7.post3 pandas-datareader-0.10.0 patsy-1.0.1 peewee-3.17.9 plotly-5.24.1 qdldl-0.1.7.post5 scs-3.2.7.post2 statsmodels-0.14.4 tenacity-9.0.0 yfinance-0.2.54 zope.interface-7.2

# %%
# !pip install pandas-ta
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.0 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.11/site-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/anubhavbanerjee/.local/lib/python3.11/site-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Installing collected packages: pandas-ta
#   DEPRECATION: pandas-ta is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pandas-ta ... done
# Successfully installed pandas-ta-0.3.14b0

# %% [markdown]
# ## Data Collection & Fetching S&P 500 Data

# %%
from statsmodels.regression.rolling import RollingOLS
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import pandas_ta
import warnings

warnings.filterwarnings('ignore')

snp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
snp500['Symbol'] = snp500['Symbol'].str.replace('.', '-')
symbols = snp500['Symbol'].unique().tolist()
endDate = '2025-03-19'
startDate = pd.to_datetime(endDate) - pd.DateOffset(365*8)
df = yf.download(tickers = symbols, start=startDate, end=endDate, auto_adjust=False).stack()
df.index.names = ['date', 'ticker']
df.columns = df.columns.str.lower()
df
# Out:
# [*********************100%***********************]  503 of 503 completed
# Price               adj close       close        high         low        open  \
# date       ticker
# 2017-03-21 A        49.549419   52.660000   53.730000   52.480000   53.279999
#            AAPL     32.481522   34.959999   35.700001   34.932499   35.527500
#            ABBV     46.380817   65.349998   66.000000   65.040001   65.959999
#            ABT      38.809986   44.799999   45.380001   44.599998   45.150002
#            ACGL     29.671204   31.203333   31.736668   31.173332   31.726667
# ...                       ...         ...         ...         ...         ...
# 2025-03-18 XYL     120.919998  120.919998  122.949997  120.639999  122.669998
#            YUM     157.300003  157.300003  157.940002  156.160004  156.710007
#            ZBH     112.879997  112.879997  113.940002  111.349998  111.660004
#            ZBRA    282.579987  282.579987  285.540009  281.920013  282.720001
#            ZTS     164.429993  164.429993  165.419998  163.240005  165.119995
#
# Price                   volume
# date       ticker
# 2017-03-21 A         1492700.0
#            AAPL    158119600.0
#            ABBV      5187400.0
#            ABT       5567100.0
#            ACGL       980100.0
# ...                        ...
# 2025-03-18 XYL       1346600.0
#            YUM       1332200.0
#            ZBH       1619300.0
#            ZBRA       323500.0
#            ZTS       1879300.0
#
# [992387 rows x 6 columns]

# %% [markdown]
# ## Calculating Technical Indicators for Each Stock
# - Garman Klass Volatility
# - RSI (Relative Strength Index)
# - Bollinger Bands
# - ATR (Average True Range)
# - MACD

# %%
df['garman-klass-vol'] = ((np.log(df['high']) - np.log(df['low']))**2)/2 - ((2*np.log(2)-1) * ((np.log(df['adj close']) - np.log(df['open'])))**2)
df['rsi'] = df.groupby(level = 1)['adj close'].transform(lambda x: pandas_ta.rsi(close = x, length = 20))
df['bb_low'] = df.groupby(level = 1)['adj close'].transform(lambda x: pandas_ta.bbands(close = np.log1p(x), length = 20).iloc[:,0])
df['bb_mid'] = df.groupby(level = 1)['adj close'].transform(lambda x: pandas_ta.bbands(close = np.log1p(x), length = 20).iloc[:,1])
df['bb_high'] = df.groupby(level = 1)['adj close'].transform(lambda x: pandas_ta.bbands(close = np.log1p(x), length = 20).iloc[:,2])
def calculate_atr(stock_data):
    atr = pandas_ta.atr(high = stock_data['high'], 
                       low = stock_data['low'],
                       close = stock_data['close'],
                       length = 14)
    return atr.sub(atr.mean()).div(atr.std())
df['atr'] = df.groupby(level = 1, group_keys = False).apply(calculate_atr)
def calculate_macd(stock_data):
    macd = pandas_ta.macd(close = stock_data['adj close'], length = 20).iloc[:, 0]
    return macd.sub(macd.mean()).div(macd.std())
df['macd'] = df.groupby(level = 1, group_keys = False).apply(calculate_macd)
df['dollar-volume'] = (df['adj close'] * df['volume']) / 1e6
df
# Out:
# Price               adj close       close        high         low        open  \
# date       ticker
# 2017-03-21 A        49.549419   52.660000   53.730000   52.480000   53.279999
#            AAPL     32.481522   34.959999   35.700001   34.932499   35.527500
#            ABBV     46.380817   65.349998   66.000000   65.040001   65.959999
#            ABT      38.809986   44.799999   45.380001   44.599998   45.150002
#            ACGL     29.671204   31.203333   31.736668   31.173332   31.726667
# ...                       ...         ...         ...         ...         ...
# 2025-03-18 XYL     120.919998  120.919998  122.949997  120.639999  122.669998
#            YUM     157.300003  157.300003  157.940002  156.160004  156.710007
#            ZBH     112.879997  112.879997  113.940002  111.349998  111.660004
#            ZBRA    282.579987  282.579987  285.540009  281.920013  282.720001
#            ZTS     164.429993  164.429993  165.419998  163.240005  165.119995
#
# Price                   volume  garman-class-vol        rsi    bb_low  \
# date       ticker
# 2017-03-21 A         1492700.0         -0.001758        NaN       NaN
#            AAPL    158119600.0         -0.002868        NaN       NaN
#            ABBV      5187400.0         -0.047800        NaN       NaN
#            ABT       5567100.0         -0.008694        NaN       NaN
#            ACGL       980100.0         -0.001573        NaN       NaN
# ...                        ...               ...        ...       ...
# 2025-03-18 XYL       1346600.0          0.000100  41.466266  4.800888
#            YUM       1332200.0          0.000059  63.526886  5.000937
#            ZBH       1619300.0          0.000219  60.548229  4.625923
#            ZBRA       323500.0          0.000081  31.882698  5.595533
#            ZTS       1879300.0          0.000081  47.634184  5.060533
#
# Price                bb_mid   bb_high       atr      macd  dollar-volume
# date       ticker
# 2017-03-21 A            NaN       NaN       NaN       NaN      73.962418
#            AAPL         NaN       NaN       NaN       NaN    5135.965204
#            ABBV         NaN       NaN       NaN       NaN     240.595852
#            ABT          NaN       NaN       NaN       NaN     216.059074
#            ACGL         NaN       NaN       NaN       NaN      29.080747
# ...                     ...       ...       ...       ...            ...
# 2025-03-18 XYL     4.851952  4.903017  0.870868 -0.797464     162.830870
#            YUM     5.049923  5.098909  1.602085  2.404496     209.555064
#            ZBH     4.677197  4.728471  0.142403  0.634891     182.786580
#            ZBRA    5.702298  5.809063  0.332612 -2.574897      91.414626
#            ZTS     5.111487  5.162440  0.856160 -0.549329     309.013285
#
# [992387 rows x 14 columns]
